# %% [markdown]
# <a href="https://colab.research.google.com/github/Asvikap/linkedin_job_data_analysis/blob/main/linkedin_ob_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv('/content/linkdin_Job_data.csv',encoding='latin-1')
df = pd.read_csv('/content/linkdin_Job_data.csv', delimiter=',', quotechar='"', encoding='utf-8')

df
# Out:
#           job_ID                                                job  \
# 0     3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2     3474349934                                 Data Analyst - WFH
# 3     3472816027                                       Data Analyst
# 4     3473311511                                       Data Analyst
# ...          ...                                                ...
# 7922  3472039871                                 Back End Developer
# 7923  3473194471                         Software Engineer - Senior
# 7924  3461005032                                             Vue JS
# 7925  3474305684                                      iOS Developer
# 7926  3459352801                     Power train function developer
#
#                             location  company_id               company_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7927 entries, 0 to 7926
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_ID              7927 non-null   int64
#  1   job                 7894 non-null   object
#  2   location            7894 non-null   object
#  3   company_id          0 non-null      float64
#  4   company_name        7892 non-null   object
#  5   work_type           7736 non-null   object
#  6   full_time_remote    7848 non-null   object
#  7   no_of_employ        7603 non-null   object
#  8   no_of_application   7887 non-null   object
#  9   posted_day_ago      7920 non-null   object
#  10  alumni              4858 non-null   object
#  11  Hiring_person       5720 non-null   object
#  12  linkedin_followers  4814 non-null   object
#  13  hiring_person_link  5720 non-null   object
#  14  job_details         7881 non-null   object
# ...

# %%
df.describe()
# Out:
#              job_ID  company_id  Column1
# count  7.927000e+03         0.0      0.0
# mean   3.466724e+09         NaN      NaN
# std    5.778011e+07         NaN      NaN
# min    1.419216e+08         NaN      NaN
# 25%    3.467367e+09         NaN      NaN
# 50%    3.471882e+09         NaN      NaN
# 75%    3.476181e+09         NaN      NaN
# max    3.477823e+09         NaN      NaN

# %%
df.columns
# Out:
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'alumni', 'Hiring_person', 'linkedin_followers',
#        'hiring_person_link', 'job_details', 'Column1'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 79

# %%
df1 = df.dropna()

# %%
df.isnull().sum()
# Out:
# job_ID                   0
# job                     33
# location                33
# company_id            7927
# company_name            35
# work_type              191
# full_time_remote        79
# no_of_employ           324
# no_of_application       40
# posted_day_ago           7
# alumni                3069
# Hiring_person         2207
# linkedin_followers    3113
# hiring_person_link    2207
# job_details             46
# Column1               7927
# dtype: int64

# %%
df['job'].value_counts()
# Out:
# Lead Java Software Engineer       172
# Data Engineer                     153
# Senior Automation Tester          146
# Business Analyst                  126
# Lead Java Developer               120
#                                  ...
# Financial Systems Manager           1
# Google Analytics Manager            1
# OIM Developer                       1
# Full Stack Developers               1
# Power train function developer      1
# Name: job, Length: 2991, dtype: int64

# %%
9df['location'].value_counts()
# Out:
# Bengaluru, Karnataka, India         1324
# India                                829
# Hyderabad, Telangana, India          671
# Chennai, Tamil Nadu, India           477
# Gurugram, Haryana, India             476
#                                     ...
# Udaipur, Rajasthan, India              1
# Greater Nagpur Area                    1
# Thiruvarur, Tamil Nadu, India          1
# Bandra, Maharashtra, India             1
# Sriperumbudur, Tamil Nadu, India       1
# Name: location, Length: 151, dtype: int64

# %%
df.columns
# Out:
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'alumni', 'Hiring_person', 'linkedin_followers',
#        'hiring_person_link', 'job_details', 'Column1'],
#       dtype='object')

# %%
df = df[['job','location','company_name','work_type','posted_day_ago','job_details']]

# %%
df
# Out:
#                                                     job  \
# 0     Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2                                    Data Analyst - WFH
# 3                                          Data Analyst
# 4                                          Data Analyst
# ...                                                 ...
# 7922                                 Back End Developer
# 7923                         Software Engineer - Senior
# 7924                                             Vue JS
# 7925                                      iOS Developer
# 7926                     Power train function developer
#
#                             location               company_name work_type  \
# 0                Delhi, Delhi, India                  Crossover    Remote
# 1            New Delhi, Delhi, India                  Crossover    Remote
# ...

# %%
df.isnull().sum()
# Out:
# job                33
# location           33
# company_name       35
# work_type         191
# posted_day_ago      7
# job_details        46
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 512

# %%
df1 = df.dropna()
df1
# Out:
#                                                     job  \
# 0     Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2                                    Data Analyst - WFH
# 3                                          Data Analyst
# 4                                          Data Analyst
# ...                                                 ...
# 7922                                 Back End Developer
# 7923                         Software Engineer - Senior
# 7924                                             Vue JS
# 7925                                      iOS Developer
# 7926                     Power train function developer
#
#                             location               company_name work_type  \
# 0                Delhi, Delhi, India                  Crossover    Remote
# 1            New Delhi, Delhi, India                  Crossover    Remote
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7714 entries, 0 to 7926
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job             7714 non-null   object
#  1   location        7714 non-null   object
#  2   company_name    7714 non-null   object
#  3   work_type       7714 non-null   object
#  4   posted_day_ago  7714 non-null   object
#  5   job_details     7714 non-null   object
# dtypes: object(6)
# memory usage: 421.9+ KB

# %%
df1.duplicated().sum()
# Out:
# 484

# %%
import seaborn as sn

# %%
sn.countplot(data = df, x = 'work_type')
plt.title('Work Type')
plt.show()

# %%
location_counts = df['location'].value_counts().head(10)

plt.figure(figsize=(10,10))
location_counts.plot(kind='bar')
plt.title('Top 10 Locations')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
location_counts = df['job'].value_counts().head(10)


plt.figure(figsize=(10,8))
location_counts.plot(kind='bar')
plt.title('Top 10 Job on linkedin')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
df['job_details']
# Out:
# 0       About the job Crossover is the world's #1 sour...
# 1       About the job Crossover is the world's #1 sour...
# 2       About the job Profile: ML EngineersExperience:...
# 3       About the job Designation: Data AnalystLocatio...
# 4       About the job The ideal candidate will use the...
#                               ...
# 7922    About the job The ideal candidate will show in...
# 7923    About the job Experience: 4 - 8 yearsProfile: ...
# 7924    About the job Role- Vue js DeveloperExperience...
# 7925    About the job Profile: iOS DeveloperExperience...
# 7926    About the job JD Powertrain Function Developer...
# Name: job_details, Length: 7927, dtype: object

# %%
new_df = df.job_details.str.split(",",expand=True)
new_df
# Out:
#                                                     0    \
# 0     About the job Crossover is the world's #1 sour...
# 1     About the job Crossover is the world's #1 sour...
# 2     About the job Profile: ML EngineersExperience:...
# 3     About the job Designation: Data AnalystLocatio...
# 4     About the job The ideal candidate will use the...
# ...                                                 ...
# 7922  About the job The ideal candidate will show in...
# 7923  About the job Experience: 4 - 8 yearsProfile: ...
# 7924  About the job Role- Vue js DeveloperExperience...
# 7925  About the job Profile: iOS DeveloperExperience...
# 7926  About the job JD Powertrain Function Developer...
#
#                                                     1    \
# 0      Trilogy. Have you got what it takes? Are you ...
# 1      Trilogy. Have you got what it takes? Are you ...
# 2                                you'll get the support
# 3                                           mathematics
# ...

# %%
plt.figure(figsize=(20,8))
df1['company_name'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='company_name'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Matplotlib currently does not support Devanagari natively.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 2369 (\N{DEVANAGARI VOWEL SIGN U}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 2348 (\N{DEVANAGARI LETTER BA}) missing from current font.
#   func(*args, **kwargs)
# ...
